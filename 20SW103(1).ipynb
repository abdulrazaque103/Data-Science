# %%
#  20SW103
# task 01
print("task 01")

x =int(input("Enter the number"))
if x <= 50:
    print("Wooden Rabbit")
elif 51 <= x <= 150:
    print("No prize")
elif 151 <= x <= 180:
    print("Water-thin mint")
elif 181 <= x <= 200:
    print("Penguin")

# task 02
print("task 02")

answer= 20
guess= int(input("Enter a number"))

if guess < answer:
      print("Oops! Your guess was too low.")
elif guess > answer:
      print("Oops! Your guess was too high.")
elif guess == answer:
      print("Nice! Your guess matched the answer!")


# task 03
print("task 03")

def calculate_tax(purchase_amount, state):

    tax_rates = {
        'CA': 0.075,
        'MN': 0.095,
        'NY': 0.089,
    }
    if state in tax_rates:
          tax_rate = tax_rates[state]
          tax_amount = purchase_amount * tax_rate
          total_amount = purchase_amount + tax_amount
          return total_amount
    else:
        return purchase_amount

purchase_amount = float(input("Enter the purchase amount: "))
state = input("Enter the state (CA, MN, or NY): ")

total_amount = calculate_tax(purchase_amount, state)
print(f"Total amount after tax: ${total_amount:.2f}")

# task 04
print("task 04")

sentence = ["the", "quick", "brown", "fox", "jumped", "over", "the",
"lazy", "dog"]

for  sent in sentence:
    print(sent)

# task 05
print("task 05")

for i in range(5,30,5):
    print(i)

# task 06
print("task 06")

names = ["Rick Sanchez", "Morty Smith", "Summer Smith", "Jerry Smith", "Beth Smith"]
first_names = [na.split()[0].lower() for na in names]
print(first_names)

# task 07
print("task 07")

multi = [x*3 for x in range(20) ]
print(multi)

# task 08
print("task 08")

scores = {
    "Rick Sanchez": 70,
    "Morty Smith": 35,
    "Summer Smith": 82,
    "Jerry Smith": 23,
    "Beth Smith": 98
}
passed = [name for name, score in scores.items() if score >= 65]

print(passed)

print("task 09")
# task 09

cast_names = ["Barney", "Robin", "Ted", "Lily", "Marshall"]
cast_heights = [72, 68, 72, 66, 76]

for cast_names,cast_heights in zip(cast_names,cast_heights):
    print("{}:{}".format(cast_names,cast_heights))

# task 10
print("task 10")

cast = ["Barney Stinson", "Robin Scherbatsky", "Ted Mosby",
"Lily Aldrin", "Marshall Eriksen"]
heights = [72, 68, 72, 66, 76]

for index, character in enumerate(cast):
    cast[index] = f"{character} {heights[index]}"

print(cast)
# Out:
# task 01
# Enter the number180
# No prive
# task 02
# Enter a number22
# Oops! Your guess was too high.
# task 03
# Enter the purchase amount: 22222
# Enter the state (CA, MN, or NY): ca
# Total amount after tax: $22222.00
# task 04
# the
# quick
# brown
# fox
# jumped
# over
# the
# lazy
# dog
# task 05
# 5
# 10
# 15
# 20
# 25
# task 06
# ['rick', 'morty', 'summer', 'jerry', 'beth']
# task 07
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57]
# task 08
# task 09
# Barney:72
# Robin:68
# Ted:72
# Lily:66
# Marshall:76
# task 10
# 0 Barney Stinson
# 1 Robin Scherbatsky
# 2 Ted Mosby
# 3 Lily Aldrin
# 4 Marshall Eriksen
